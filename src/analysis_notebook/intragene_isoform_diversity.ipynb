# %% [markdown]
# # Evaluate isoforms diversity for each gene

# %%
import sys
sys.path.append("..")
import pannzer_out_api as poa

import statistics as stats
import pandas as pd

gogo_dir = "~/Software/GOGO"

# %% [markdown]
# ## Loading data
# We'll try with chr1 of gencode human data.

# %%
chr1 = poa.parse_pannzer_annotation('../../data/pannzer_output/chr21.all.nr_off.out', 'chr1')

# %% [markdown]
# Quick test : our functions works.

# %%
i = 0
for gene in chr1:
    i += 1
    gene = chr1[gene]
    gene.id#print(gene.id)
    print(gene.number_of_isoforms())
    gene.diversity_by_pair(poa.jaccard_index)#print(gene.diversity_by_pair(poa.jaccard_index))
    gene.diversity_by_pair(poa.dice_coefficient)#print(gene.diversity_by_pair(poa.dice_coefficient))
    gene.diversity_by_pair(poa.overlap_coefficient)#print(gene.diversity_by_pair(poa.overlap_coefficient))
    gene.go_redundance_metric()#print(gene.go_redundance_metric())
    gene.stdev_number_of_go_by_isoform()#print(gene.stdev_number_of_go_by_isoform())
    print(gene.intra_gene_gogo_similarity(gogo_dir='~/Software/GOGO'))
    if i % 10 == 0:
        print(i)
# Out:
# 5
# (0.6, 0.852, 0.6)
# 1
# (1, 1, 1)
# 2
# (0.0, 0.565, 0.56)
# 7
# (1.0, 0.9880952380952382, 0.9947619047619052)
# 1
# (1, 1, 1)
# 1
# (1, 1, 1)
# 5
# (0.6, 0.8378, 0.5622)
# 5
# (0.4, 0.4, 0.4)
# 6
# (0.32393333333333335, 0.4274666666666667, 0.7753333333333334)
# 5
# (0.2636, 0.4311, 0.3638)
# 10
# 3
# (0.3333333333333333, 0.3273333333333333, 0.3333333333333333)
# 4
# (1.0, 1.0, 1.0)
# 7
# (1.0, 1.0, 1.0)
# 2
# (0.0, 0.0, 0.0)
# 2
# (1.0, 1.0, 1.0)
# 3
# (1.0, 1.0, 1.0)
# 4
# (1.0, 1.0, 1.0)
# 7
# (1.0, 1.0, 1.0)
# 2
# (1.0, 1.0, 1.0)
# 10
# (0.5823999999999998, 0.8951999999999998, 0.8105333333333324)
# 20
# 3
# (1.0, 1.0, 1.0)
# 7
# (0.7366190476190475, 0.8941904761904761, 0.9690476190476189)
# 2
# (0.318, 0.0, 0.85)
# 3
# (0.9886666666666667, 0.9113333333333333, 0.996)
# 5
# (0.9987999999999999, 0.9411999999999999, 0.9898)
# 1
# (1, 1, 1)
# 4
# (0.5, 0.5, 0.5)
# 5
# (0.6705999999999998, 0.5817, 0.9468)
# 12
# (1.0, 1.0, 0.5151515151515151)
# 12
# ...

# %%
# chr1.genes['ENSG00000157601'].intra_gene_gogo_similarity(gogo_dir)

chr1.genes['ENSG00000205758'].intra_gene_gogo_similarity(gogo_dir)
# Out:
# (0.5751633986928104, 0.5265424836601308, 0.399346405228758)

# %%
0.399346405228758*153
# Out:
# 61.09999999999997

# %%
0.3993464052287581*153
# Out:
# 61.09999999999999

# %%
chr1a.genes['ENSG00000205758'].intra_gene_gogo_similarity(gogo_dir)
# Out:
# ENST00000381554.8 ENST00000290244.9 1 1 1
# ENST00000381554.8 ENST00000381540.7 1 1 1
# ENST00000381554.8 ENST00000452420.5 0 0 0
# ENST00000381554.8 ENST00000441940.5 0 0 0
# ENST00000381554.8 ENST00000445393.5 0 0 0
# ENST00000381554.8 ENST00000437996.5 0 0 0
# ENST00000381554.8 ENST00000361534.6 1 1 1
# ENST00000381554.8 ENST00000429827.5 0 0 0.455
# ENST00000381554.8 ENST00000420072.5 0 0.932 0.455
# ENST00000381554.8 ENST00000440526.5 1 0.967 1
# ENST00000381554.8 ENST00000414079.5 0 0 0
# ENST00000381554.8 ENST00000426935.5 0 0 0.455
# ENST00000381554.8 ENST00000431177.5 0 0 0.455
# ENST00000381554.8 ENST00000417979.5 0 0 0
# ENST00000381554.8 ENST00000413017.2 0 0 0
# ENST00000381554.8 ENST00000438788.1 0 0 0
# ENST00000381554.8 ENST00000399442.1 0 0 0
# ENST00000290244.9 ENST00000381540.7 1 1 1
# ENST00000290244.9 ENST00000452420.5 0 0 0
# ENST00000290244.9 ENST00000441940.5 0 0 0
# ENST00000290244.9 ENST00000445393.5 0 0 0
# ENST00000290244.9 ENST00000437996.5 0 0 0
# ...

# %%
for t in chr1.genes['ENSG00000205758'].transcripts:
    print(t)
    print(chr1.genes['ENSG00000205758'][t].get_go_term_id())
# Out:
# ENST00000381554.8
# ['GO:0016491', 'GO:1901661', 'GO:0005829', 'GO:0003824', 'GO:0042180', 'GO:0016020', 'GO:0003960', 'GO:0044281', 'GO:0005737', 'GO:0050661', 'GO:0005622', 'GO:0044237', 'GO:0016655', 'GO:0071704', 'GO:0110165', 'GO:0016651', 'GO:0008152', 'GO:0030554', 'GO:0009987', 'GO:0017076', 'GO:0000166', 'GO:1901265', 'GO:0036094', 'GO:1901363', 'GO:0097159', 'GO:0005488']
# ENST00000290244.9
# ['GO:0016491', 'GO:1901661', 'GO:0005829', 'GO:0003824', 'GO:0042180', 'GO:0016020', 'GO:0003960', 'GO:0044281', 'GO:0005737', 'GO:0050661', 'GO:0005622', 'GO:0044237', 'GO:0016655', 'GO:0071704', 'GO:0110165', 'GO:0016651', 'GO:0008152', 'GO:0030554', 'GO:0009987', 'GO:0017076', 'GO:0000166', 'GO:1901265', 'GO:0036094', 'GO:1901363', 'GO:0097159', 'GO:0005488']
# ENST00000381540.7
# ...

# %%
for t in chr1.genes['ENSG00000142197'].transcripts:
    print(t)
    print(chr1.genes['ENSG00000142197'][t].get_go_term_id())
# Out:
# ENST00000693273.1
# ['GO:0006895', 'GO:0005829', 'GO:0006892', 'GO:0005737', 'GO:0016482', 'GO:0005622', 'GO:0048193', 'GO:0110165', 'GO:0016192', 'GO:0046907', 'GO:0051649', 'GO:0051641', 'GO:0006810', 'GO:0051234', 'GO:0051179', 'GO:0009987']
# ENST00000691173.1
# ...

# %%
poa.gogo_similarity_between_transcript(chr1.genes['ENSG00000142197']['ENST00000691173.1'], chr1.genes['ENSG00000142197']['ENST00000693273.1'], gogo_dir)
# Out:
# (0.718, 0.61, 0)

# %%
5.154/6
# Out:
# 0.859

# %% [markdown]
# Let's create a dataframe with our results.

# %%
shuffle : poa.Annotation = poa.make_shuffle_copy(chr1)

# %%
data = pd.DataFrame()
data['Gene'] = chr1.genes.keys()
data['Type'] = "Observed"
data['Number of isoform'] = data['Gene'].apply(chr1.get_gene).apply(poa.Gene.number_of_isoforms)
data['Jaccard Index'] = data['Gene'].apply(chr1.get_gene).apply(poa.Gene.diversity_by_pair, similarity_function=poa.jaccard_index)
data['Dice coefficient'] = data['Gene'].apply(chr1.get_gene).apply(poa.Gene.diversity_by_pair, similarity_function=poa.dice_coefficient)
data['Overlap coefficient'] = data['Gene'].apply(chr1.get_gene).apply(poa.Gene.diversity_by_pair, similarity_function=poa.overlap_coefficient)
data['Redundance metric'] = data['Gene'].apply(chr1.get_gene).apply(poa.Gene.go_redundance_metric)
data['Stdev number GO term'] = data['Gene'].apply(chr1.get_gene).apply(poa.Gene.stdev_number_of_go_by_isoform)
# similarity = data['Gene'].apply(chr1.get_gene).apply(poa.Gene.intra_gene_gogo_similarity, gogo_dir=gogo_dir)
# data['BP similarity'] = similarity.apply(lambda x : x[0])
# data['CC similarity'] = similarity.apply(lambda x : x[1])
# data['MF similarity'] = similarity.apply(lambda x : x[2])
data
# Out:
#                 Gene      Type  Number of isoform  Jaccard Index  \
# 0    ENSG00000274391  Observed                  5       0.611765
# 1    ENSG00000277282  Observed                  1       1.000000
# 2    ENSG00000166351  Observed                  2       0.069767
# 3    ENSG00000188992  Observed                  7       0.965608
# 4    ENSG00000185272  Observed                  1       1.000000
# ..               ...       ...                ...            ...
# 216  ENSG00000160299  Observed                 10       0.669444
# 217  ENSG00000286224  Observed                  1       1.000000
# 218  ENSG00000160305  Observed                  6       0.287049
# 219  ENSG00000160307  Observed                  3       0.333333
# 220  ENSG00000160310  Observed                 10       0.478676
#
#      Dice coefficient  Overlap coefficient  Redundance metric  \
# 0            0.622857                  1.0           0.757353
# ...

# %%
reassignment = pd.DataFrame()
reassignment['Gene'] = shuffle.genes.keys()
reassignment['Type'] = "Expected"
reassignment['Number of isoform'] = reassignment['Gene'].apply(shuffle.get_gene).apply(poa.Gene.number_of_isoforms)
reassignment['Jaccard Index'] = reassignment['Gene'].apply(shuffle.get_gene).apply(poa.Gene.diversity_by_pair, similarity_function=poa.jaccard_index)
reassignment['Dice coefficient'] = reassignment['Gene'].apply(shuffle.get_gene).apply(poa.Gene.diversity_by_pair, similarity_function=poa.dice_coefficient)
reassignment['Overlap coefficient'] = reassignment['Gene'].apply(shuffle.get_gene).apply(poa.Gene.diversity_by_pair, similarity_function=poa.overlap_coefficient)
reassignment['Redundance metric'] = reassignment['Gene'].apply(shuffle.get_gene).apply(poa.Gene.go_redundance_metric)
reassignment['Stdev number GO term'] = reassignment['Gene'].apply(shuffle.get_gene).apply(poa.Gene.stdev_number_of_go_by_isoform)
reassignment
# Out:
#                 Gene      Type  Number of isoform  Jaccard Index  \
# 0    ENSG00000274391  Expected                  5       0.047501
# 1    ENSG00000277282  Expected                  1       1.000000
# 2    ENSG00000166351  Expected                  2       0.000000
# 3    ENSG00000188992  Expected                  7       0.183989
# 4    ENSG00000185272  Expected                  1       1.000000
# ..               ...       ...                ...            ...
# 216  ENSG00000160299  Expected                 10       0.112376
# 217  ENSG00000286224  Expected                  1       1.000000
# 218  ENSG00000160305  Expected                  6       0.108783
# 219  ENSG00000160307  Expected                  3       0.047101
# 220  ENSG00000160310  Expected                 10       0.114509
#
#      Dice coefficient  Overlap coefficient  Redundance metric  \
# 0            0.086598             0.673700           0.043675
# ...

# %%
pd.concat((data, reassignment))
# Out:
#                 Gene      Type  Number of isoform  Jaccard Index  \
# 0    ENSG00000274391  Observed                  5       0.611765
# 1    ENSG00000277282  Observed                  1       1.000000
# 2    ENSG00000166351  Observed                  2       0.069767
# 3    ENSG00000188992  Observed                  7       0.965608
# 4    ENSG00000185272  Observed                  1       1.000000
# ..               ...       ...                ...            ...
# 216  ENSG00000160299  Expected                 10       0.112376
# 217  ENSG00000286224  Expected                  1       1.000000
# 218  ENSG00000160305  Expected                  6       0.108783
# 219  ENSG00000160307  Expected                  3       0.047101
# 220  ENSG00000160310  Expected                 10       0.114509
#
#      Dice coefficient  Overlap coefficient  Redundance metric  \
# 0            0.622857             1.000000           0.757353
# ...

# %% [markdown]
# Let's check the summary.

# %%
data.describe()
# Out:
#        Number of isoform  Jaccard Index  Dice coefficient  \
# count         221.000000     221.000000        221.000000
# mean            4.728507       0.717273          0.735786
# std             4.946859       0.320005          0.308929
# min             1.000000       0.000000          0.000000
# 25%             1.000000       0.412186          0.440480
# 50%             3.000000       0.943667          0.970381
# 75%             7.000000       1.000000          1.000000
# max            37.000000       1.000000          1.000000
#
#        Overlap coefficient  Redundance metric  Stdev number GO term
# count           221.000000         221.000000            221.000000
# mean              0.997651           0.734614             19.072891
# std               0.014285           0.318692             29.534257
# min               0.833333           0.000000              0.000000
# 25%               1.000000           0.493088              0.000000
# ...

# %% [markdown]
# Not as detailed as I want. Let's create our own.

# %%
def precise_quantile(sample, n):
    return stats.quantiles(sample, n = 100)[n-1]

# %%
summary = pd.DataFrame()
summary['Metrics'] = data.columns[1:]
summary['Mean'] = summary['Metrics'].apply(data.get).apply(stats.fmean, axis = 1)
summary['Harmonic Mean'] = summary['Metrics'].apply(data.get).apply(stats.harmonic_mean, axis = 1)
summary['Median'] = summary['Metrics'].apply(data.get).apply(stats.median, axis = 1)
summary['Q25'] = summary['Metrics'].apply(data.get).apply(precise_quantile, n=25, axis = 1)
summary['Q75'] = summary['Metrics'].apply(data.get).apply(precise_quantile, n=75, axis = 1)
summary['Sample Variance'] = summary['Metrics'].apply(data.get).apply(stats.variance, axis = 1)
summary['Sample Standard Deviation'] = summary['Metrics'].apply(data.get).apply(stats.stdev, axis = 1)
summary['Population Variance'] = summary['Metrics'].apply(data.get).apply(stats.pvariance, axis = 1)
summary['Population Standard Deviation'] = summary['Metrics'].apply(data.get).apply(stats.pstdev, axis = 1)
summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4 summary['Harmonic Mean'] = summary['Metrics'].apply(data.get).apply(stats.harmonic_mean, axis = 1)
#       5 summary['Median'] = summary['Metrics'].apply(data.get).apply(stats.median, axis = 1)
# ----> 6 summary['Q25'] = summary['Metrics'].apply(data.get).apply(precise_quantile, n=25, axis = 1)
#       7 summary['Q75'] = summary['Metrics'].apply(data.get).apply(precise_quantile, n=75, axis = 1)
#       8 summary['Sample Variance'] = summary['Metrics'].apply(data.get).apply(stats.variance, axis = 1)
#
# NameError: name 'precise_quantile' is not defined

# %%
summary = pd.DataFrame()
summary['Metrics'] = data.columns[2:]
summary['Mean (observed)'] = summary['Metrics'].apply(data.get).apply(stats.fmean, axis = 1)
summary['Mean (expected)'] = summary['Metrics'].apply(reassignment.get).apply(stats.fmean, axis = 1)
summary['Harmonic Mean (observed)'] = summary['Metrics'].apply(data.get).apply(stats.harmonic_mean, axis = 1)
summary['Harmonic Mean (expected)'] = summary['Metrics'].apply(reassignment.get).apply(stats.harmonic_mean, axis = 1)
summary['Median (observed)'] = summary['Metrics'].apply(data.get).apply(stats.median, axis = 1)
summary['Median (expected)'] = summary['Metrics'].apply(reassignment.get).apply(stats.median, axis = 1)
summary['Q25 (observed)'] = summary['Metrics'].apply(data.get).apply(precise_quantile, n=25, axis = 1)
summary['Q25 (expected)'] = summary['Metrics'].apply(reassignment.get).apply(precise_quantile, n=25, axis = 1)
summary['Q75 (observed)'] = summary['Metrics'].apply(data.get).apply(precise_quantile, n=75, axis = 1)
summary['Q75 (expected)'] = summary['Metrics'].apply(reassignment.get).apply(precise_quantile, n=75, axis = 1)
summary['Sample Variance (observed)'] = summary['Metrics'].apply(data.get).apply(stats.variance, axis = 1)
summary['Sample Variance (expected)'] = summary['Metrics'].apply(reassignment.get).apply(stats.variance, axis = 1)
summary['Sample Standard Deviation (observed)'] = summary['Metrics'].apply(data.get).apply(stats.stdev, axis = 1)
summary['Sample Standard Deviation (expected)'] = summary['Metrics'].apply(reassignment.get).apply(stats.stdev, axis = 1)
summary['Population Variance (observed)'] = summary['Metrics'].apply(data.get).apply(stats.pvariance, axis = 1)
summary['Population Variance (expected)'] = summary['Metrics'].apply(reassignment.get).apply(stats.pvariance, axis = 1)
summary['Population Standard Deviation (observed)'] = summary['Metrics'].apply(data.get).apply(stats.pstdev, axis = 1)
summary['Population Standard Deviation (expected)'] = summary['Metrics'].apply(reassignment.get).apply(stats.pstdev, axis = 1)
summary
# Out:
#                 Metrics  Mean (observed)  Mean (expected)  \
# 0     Number of isoform         4.728507         4.728507
# 1         Jaccard Index         0.717273         0.406696
# 2      Dice coefficient         0.735786         0.431573
# 3   Overlap coefficient         0.997651         0.753984
# 4     Redundance metric         0.734614         0.376469
# 5  Stdev number GO term        19.072891        35.811419
#
#    Harmonic Mean (observed)  Harmonic Mean (expected)  Median (observed)  \
# 0                  2.013887                  2.013887           3.000000
# 1                  0.000000                  0.000000           0.943667
# 2                  0.000000                  0.000000           0.970381
# 3                  0.997419                  0.546020           1.000000
# 4                  0.000000                  0.000000           0.941441
# 5                  0.000000                  0.000000           1.600000
#
# ...
